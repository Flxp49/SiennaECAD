# %%
# This is to convert txt files containing .ADD_TER to standard format

# %%
import pandas as pd
import csv

# %%
def find_first_occurence_of_add_ter(original_data):
    add_ter_index = -1
    for i in range(0, len(original_data)):
        if ".ADD_TER" in original_data[i]:
            add_ter_index = i
            break
    
    return add_ter_index

# %%
def get_mappings(focused_data):
    final_data = list()

    column_one = ""
    column_two = ""
    for i in focused_data:
        # Updating column one if the row is .ADD_TER
        if ".ADD_TER" in i:
            column_one = i[3]
            column_two = i[1] + i[2]

        # Updating the column two details
        elif ".TER" in i:
            column_two = i[1] + i[2]
        else:
            column_two = i[0] + i[1]

        temp_dict = {
            "column_one": column_one,
            "column_two": column_two
        }
        final_data.append(temp_dict)

    return final_data

# %%
def dump_final_data_to_file(final_data, filename):
    print(final_data)
    final_filename = filename
    
    with open(filename, mode='w', newline='') as csv_file:
        fieldnames = ['column_one', 'column_two']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        writer.writeheader()
        writer.writerows(final_data)
    
    print("final_data written to ", final_filename)

# %%
def process_data(filename, output_csv_filename):
    # Load the file to process
    original_data = list()
    # delim = "  "
    with open(filename, "r") as file:
        for line in file.readlines():
            temp_list = line.split()
            if temp_list != []:
                original_data.append(line.split())
              
    # Process the file and get the mappings
    first_occurence_of_add_ter = find_first_occurence_of_add_ter(original_data)
    if first_occurence_of_add_ter != -1:
        focused_data = original_data[first_occurence_of_add_ter:-1]
        final_data = get_mappings(focused_data)
        dump_final_data_to_file(final_data, output_csv_filename)
    else:
        print("Cannot find .ADD_TER in the data file, exiting...")

# %%
def remove_quotations(file):
    df=pd.read_csv(file).replace('"', ' ')
    #df=df.applymap(lambda x: x.replace('"', ' '))
    df=df[['column_one','column_two']]
    return df

# %%
while True:
    option = int(input("Enter 1 to convert a NetList or 0 to quit"))

    if option == 0:
        break

    fileName1 = input("Enter the name of the first NetList file to check\n")
    # fileName2 = input("Enter the name of the second NetList file to check\n")
    # destinationFile1 = input("Enter the name of the csv file to store the converted data into: ")
    # destinationFile2 = input("Enter the name of the csv file to store the converted data into: ")

    filename_list = [fileName1]
    # filename_list = [fileName1, fileName2]

    for index, fileName in enumerate(filename_list):
        file_name = "DX-Netlist-f"+str(index+1)+".csv"
        position = fileName.find('.')
        netlist_format = fileName[position+1:]

        if netlist_format == 'txt':
            process_data(fileName, file_name)

            # df = pd.read_csv(file_name, skipinitialspace=True).replace('"', '', regex=True)
          #  df=df.iloc[: ,0:]
        # df.reset_index(drop=True,inplace=True)
           # if '"' in df['column_one']:

            # df = remove_quotations(file_name)
            # df.to_csv(file_name, index=False)
# Out:
# [{'column_one': '$12N3011', 'column_two': 'DL1A'}, {'column_one': '$12N3011', 'column_two': 'R2141'}, {'column_one': '$2N1496', 'column_two': 'RN5113'}, {'column_one': '$2N1496', 'column_two': 'U1R10'}, {'column_one': '$5N2577', 'column_two': 'U142'}, {'column_one': '$5N2577', 'column_two': 'C702'}, {'column_one': '$6N3299', 'column_two': 'U1756'}, {'column_one': '$6N3299', 'column_two': 'TP741'}, {'column_one': 'RF-TxRx-D1', 'column_two': 'TP1561'}, {'column_one': 'RF-TxRx-D1', 'column_two': 'RN22'}, {'column_one': 'RF-TxRx-D1', 'column_two': 'U1D14'}, {'column_one': '$2N445', 'column_two': 'U1L1'}, {'column_one': '$2N445', 'column_two': 'R2192'}, {'column_one': '$5N1204', 'column_two': 'U1221'}, {'column_one': '$5N1204', 'column_two': 'L72'}, {'column_one': 'QUADSPI_BK1_IO1', 'column_two': 'RN552'}, {'column_one': 'QUADSPI_BK1_IO1', 'column_two': 'U22'}, {'column_one': '$7N1734', 'column_two': 'U1761'}, {'column_one': '$7N1734', 'column_two': 'L362'}, {'column_one': '$7N1734', 'column_two': 'C1461'}, {'column_one': '$7N2131', 'column_two': 'U193'}, {'column_one': '$7N2131', 'column_two': 'R1491'}, {'column_one': '$7N2131', 'column_two': 'R1551'}, {'column_one': 'TMS', 'column_two': 'U1A15'}, {'column_one': 'TMS', 'column_two': 'P1022'}, {'column_one': '$12N1210', 'column_two': 'C2421'}, {'column_one': '$12N1210', 'column_two': 'U284'}, {'column_one': '$12N1210', 'column_two': 'R2001'}, {'column_one': '$12N1210', 'column_two': 'R1982'}, {'column_one': '$2N2316', 'column_two': 'Q101'}, {'column_one': '$2N2316', 'column_two': 'R2241'}, {'column_one': '$6N2529', 'column_two': 'R1201'}, {'column_one': '$6N2529', 'column_two': 'C1191'}, {'column_one': '$6N2529', 'column_two': 'TP381'}, {'column_one': '$6N2529', 'column_two': 'U17114'}, {'column_one': '$2N520', 'column_two': 'U1N13'}, {'column_one': '$2N520', 'column_two': 'RN5515'}, {'column_one': 'FMC_D1', 'column_two': 'U3B9'}, {'column_one': 'FMC_D1', 'column_two': 'RN506'}, {'column_one': '$8N6534', 'column_two': 'U223'}, {'column_one': '$8N6534', 'column_two': 'C2052'}, {'column_one': 'FMC_SDNCAS', 'column_two': 'U3F7'}, {'column_one': 'FMC_SDNCAS', 'column_two': 'RN545'}, {'column_one': 'GNSS-1PPS', 'column_two': 'R32'}, {'column_one': 'GNSS-1PPS', 'column_two': 'U1B8'}, {'column_one': '$5N1349', 'column_two': 'U1223'}, {'column_one': '$5N1349', 'column_two': 'U1222'}, {'column_one': '$5N1349', 'column_two': 'C821'}, {'column_one': '$5N1349', 'column_two': 'R2182'}, {'column_one': '$5N1349', 'column_two': 'C661'}, {'column_one': '$6N1205', 'column_two': 'U1796'}, {'column_one': '$6N1205', 'column_two': 'C942'}, {'column_one': '$6N2136', 'column_two': 'C1171'}, {'column_one': '$6N2136', 'column_two': 'TP361'}, {'column_one': '$6N2136', 'column_two': 'U17116'}, {'column_one': '$6N2136', 'column_two': 'R1192'}, {'column_one': 'TCK', 'column_two': 'P1024'}, {'column_one': 'TCK', 'column_two': 'U1A14'}, {'column_one': '$1N2726', 'column_two': 'U1R1'}, {'column_one': '$1N2726', 'column_two': 'L32'}, {'column_one': '$1N2726', 'column_two': 'C351'}, {'column_one': '$7N1407', 'column_two': 'L332'}, {'column_one': '$7N1407', 'column_two': 'U1758'}, {'column_one': '$7N1407', 'column_two': 'C1431'}, {'column_one': '$8N1951', 'column_two': 'FL2E'}, {'column_one': '$8N1951', 'column_two': 'L522'}, {'column_one': '$12N890', 'column_two': 'Q71'}, {'column_one': '$12N890', 'column_two': 'R531'}, {'column_one': '$12N890', 'column_two': 'R931'}, {'column_one': '$2N1401', 'column_two': 'U1R8'}, {'column_one': '$2N1401', 'column_two': 'RN5016'}, {'column_one': '$2N673', 'column_two': 'U1J2'}, {'column_one': '$2N673', 'column_two': 'RN5213'}, {'column_one': '$2N673', 'column_two': 'TP1511'}, {'column_one': '$13N550', 'column_two': 'R2591'}, {'column_one': '$13N550', 'column_two': 'Q121'}, {'column_one': '$6N11829', 'column_two': 'R1001'}, {'column_one': '$6N11829', 'column_two': 'C1152'}, {'column_one': '$6N2143', 'column_two': 'C1172'}, {'column_one': '$6N2143', 'column_two': 'R1021'}, {'column_ ...
# final_data written to  DX-Netlist-f1.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-c0c5029a07c5> in <module>
#       1 while True:
# ----> 2     option = int(input("Enter 1 to convert a NetList or 0 to quit"))
#       3
#       4     if option == 0:
#       5         break
#
# ValueError: invalid literal for int() with base 10: ''
